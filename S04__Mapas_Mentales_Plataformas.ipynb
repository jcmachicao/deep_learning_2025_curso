# %% [markdown]
# <a href="https://colab.research.google.com/github/jcmachicao/deep_learning_2025_curso/blob/main/S04__Mapas_Mentales_Plataformas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![mermaid-diagram-2025-09-30-184846.png](data:image/png;base64,...)

# %% [markdown]
# ![mermaid-diagram-2025-09-30-185059.png](data:image/png;base64,...)

# %% [markdown]
# ![mermaid-diagram-2025-09-30-210130.png](data:image/png;base64,...)
